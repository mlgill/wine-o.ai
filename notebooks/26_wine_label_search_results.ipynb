# %%
import pandas as pd
import numpy as np
import os
import h5py
import dill
from PIL import Image

# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Search image

# %%
img = Image.open('/home/ubuntu/projects/demo/search/query_snooth_dot_com_6799.png')
plt.imshow(img)

# %% [markdown]
# ## Without RANSAC

# %%
img = Image.open('/home/ubuntu/projects/demo/search/results_snooth_dot_com_6799.png')
f = plt.figure()
f.set_size_inches(20,10)
ax = plt.axes()
ax.imshow(img, aspect="auto")

# %% [markdown]
# ## With RANSAC

# %%
img = Image.open('/home/ubuntu/projects/demo/search/results_RANSAC_snooth_dot_com_6799.png')
f = plt.figure()
f.set_size_inches(20,10)
ax = plt.axes()
ax.imshow(img, aspect="auto")
